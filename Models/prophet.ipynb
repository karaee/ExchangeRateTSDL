# %% [markdown]
# <a href="https://colab.research.google.com/github/ee-689-boun/tsdl/blob/main/prophet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance
# Out:
# ...
#      |████████████████████████████████| 5.5MB 6.3MB/s
# ...
#   Created wheel for yfinance: filename=yfinance-0.1.55-py2.py3-none-any.whl size=22616 sha256=bf75de34c43a0b7da7b4420d92901b9e76e5ef2d87c968146269e87d80d0aa7f
#   Stored in directory: /root/.cache/pip/wheels/04/98/cc/2702a4242d60bdc14f48b4557c427ded1fe92aedf257d4565c
# Successfully built yfinance
# ...
#   Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ...

# %%
from pandas_datareader import data
data = data.DataReader('DEXUSEU', 'fred')

# %%
data = data.reset_index()
data.columns = ["ds", "y"]

# %%
from fbprophet import Prophet

m = Prophet(daily_seasonality=False)
m.fit(data)

future = m.make_future_dataframe(365, freq='D')

output = m.predict(future)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.

# %%
m.plot_components(output)

# %%
m.plot(output)
